# %%
import pandas as pd
df = pd.read_excel('autoreg_motor.xlsx')
df.head()
# Out:
#       yhat  subject#  age  sex  test_time  Jitter(%)  Jitter(Abs)  \
# 0  21.9536         1   72    0     5.6431    0.00662     0.000034
# 1  28.0881         1   72    0    12.6660    0.00300     0.000017
# 2  28.4905         1   72    0    19.6810    0.00481     0.000025
# 3  28.5803         1   72    0    25.6470    0.00528     0.000027
# 4  28.8301         1   72    0    33.6420    0.00335     0.000020
#
#    Jitter(RAP)  Jitter(PPQ5)  Jitter(DDP)  ...      PPE  motor_UPDRS  \
# 0      0.00401       0.00317      0.01204  ...  0.16006       28.199
# 1      0.00132       0.00150      0.00395  ...  0.10810       28.447
# 2      0.00205       0.00208      0.00616  ...  0.21014       28.695
# 3      0.00191       0.00264      0.00573  ...  0.33277       28.905
# 4      0.00093       0.00130      0.00278  ...  0.19361       29.187
#
#    total_UPDRS  Factor1  Factor2  Factor3  Factor4  Factor5  Factor6  Factor7
# ...

# %%
subject_time = df[["subject#", "test_time", "motor_UPDRS", "yhat"]]
subject_time.head()
# Out:
#    subject#  test_time  motor_UPDRS     yhat
# 0         1     5.6431       28.199  21.9536
# 1         1    12.6660       28.447  28.0881
# 2         1    19.6810       28.695  28.4905
# 3         1    25.6470       28.905  28.5803
# 4         1    33.6420       29.187  28.8301

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Create the subplots
n_cols = 7
n_rows = 6
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols)
fig.set_size_inches(20, 10)
for i in range(42):
    data = subject_time[subject_time["subject#"] == i+1]
    axes[i//n_cols,i%n_cols].scatter(x = data["test_time"], y = data["motor_UPDRS"], color='blue')
    axes[i//n_cols,i%n_cols].scatter(data["test_time"], data["yhat"], color='black')
plt.tight_layout()

# %%
import pandas as pd
df = pd.read_excel('autoreg_total.xlsx')
df.head()
# Out:
#       yhat  subject#  age  sex  test_time  Jitter(%)  Jitter(Abs)  \
# 0  30.0342         1   72    0     5.6431    0.00662     0.000034
# 1  34.3898         1   72    0    12.6660    0.00300     0.000017
# 2  35.0543         1   72    0    19.6810    0.00481     0.000025
# 3  35.3552         1   72    0    25.6470    0.00528     0.000027
# 4  35.8308         1   72    0    33.6420    0.00335     0.000020
#
#    Jitter(RAP)  Jitter(PPQ5)  Jitter(DDP)  ...      PPE  motor_UPDRS  \
# 0      0.00401       0.00317      0.01204  ...  0.16006       28.199
# 1      0.00132       0.00150      0.00395  ...  0.10810       28.447
# 2      0.00205       0.00208      0.00616  ...  0.21014       28.695
# 3      0.00191       0.00264      0.00573  ...  0.33277       28.905
# 4      0.00093       0.00130      0.00278  ...  0.19361       29.187
#
#    total_UPDRS  Factor1  Factor2  Factor3  Factor4  Factor5  Factor6  Factor7
# ...

# %%
subject_time = df[["subject#", "test_time", "total_UPDRS", "yhat"]]
subject_time.head()
# Out:
#    subject#  test_time  total_UPDRS     yhat
# 0         1     5.6431       34.398  30.0342
# 1         1    12.6660       34.894  34.3898
# 2         1    19.6810       35.389  35.0543
# 3         1    25.6470       35.810  35.3552
# 4         1    33.6420       36.375  35.8308

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Create the subplots
n_cols = 7
n_rows = 6
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols)
fig.set_size_inches(20, 10)
for i in range(42):
    data = subject_time[subject_time["subject#"] == i+1]
    axes[i//n_cols,i%n_cols].scatter(x = data["test_time"], y = data["total_UPDRS"], color='green')
    axes[i//n_cols,i%n_cols].scatter(data["test_time"], data["yhat"], color='black')
plt.tight_layout()
